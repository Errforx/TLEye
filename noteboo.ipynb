# %%
import openvino as ov
import torch

model = torch.load("yolov11_model.pt")  # load a custom trained model

# Export the model
ov_model = ov.convert_model(model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 model = torch.load("yolov11_model.pt")  # load a custom trained model
#       6 # Export the model
# ----> 7 model.export(format="openvino")
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'export'
