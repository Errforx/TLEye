# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EAH1p58mzetc0x2NM25Z")
project = rf.workspace("e-vgxdx").project("emergency-vehicles-jjmxm-z7wz6")
version = project.version(1)
dataset = version.download("yolov11")
